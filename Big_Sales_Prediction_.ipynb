# %% [markdown]
#   # BIG SALES PREDICTIONS
#
# *The project is to predict the sales of items in different outlets based on various features such as item characteristics and outlet properties. This involves analyzing a dataset that includes information about items and outlets to build a predictive model that can forecast sales for new items or outlets*.
#
# *The dataset consists of various features related to items and outlets, including*:
#
# *  Item Identifier
# *  Item Weight
# *  Item Fat Content
# *  Item Visibility
# *  Item Type
# *  Item MRP (Maximum Retail Price)
# *  Outlet Identifier
# *  Outlet Establishment Year
# *  Outlet Size
# *  Outlet Location Type
# *  Outlet Type
# *  Item Outlet Sales

# %% [markdown]
# # Objective
#
# *The primary objective for big sales prediction would be to develop a predictive model that can accurately estimate the Item Outlet Sales for different products based on the given features. This will help in understanding the sales patterns and forecasting future sales, enabling better inventory management, pricing strategies, and marketing efforts.*
#
# *Here are some key objectives for this project*:
#
# * Data Understanding and Preprocessing
# * Exploratory Data Analysis (EDA)
# * Feature Engineering
# * Model Building
# * Prediction and Deployment
# * Reporting

# %% [markdown]
#   # Data Source
# *The data source for the big sales prediction typically includes a variety of datasets that provide detailed information about sales transactions, product details, and outlet characteristics. These datasets can be obtained from multiple sources, including*:
#
# *  Retail Sales Data
# *  Product Information
# *  Outlet Information
# *  Market and Consumer Data
# *  External Factors

# %% [markdown]
# # Import Library
#
# *To work on the big sales prediction project, we will need to import several essential libraries for data manipulation, visualization, and model building*
#
# ```
# import pandas as pd
# ```

# %% [markdown]
# # Import Data
#
# ```
# data = pd.read_csv(r'/content/drive/MyDrive/datasets/big_sales_prediction.csv')
# data
# ```

# %%
import pandas as pd
data = pd.read_csv(r'/content/drive/MyDrive/datasets/big_sales_prediction.csv')
data
# Out:
#    Item Identifier  Item Weight Item Fat Content  Item Visibility  \
# 0            FD001         12.5          Low Fat             0.02
# 1            FD002         10.0          Regular             0.03
# 2            FD003          9.3          Low Fat             0.05
# 3            FD004          5.5          Regular             0.07
# 4            FD005          6.8          Low Fat             0.09
# 5            FD006          7.2          Regular             0.02
# 6            FD007          8.1          Low Fat             0.04
# 7            FD008         11.0          Regular             0.06
# 8            FD009         13.5          Low Fat             0.08
# 9            FD010          7.5          Regular             0.03
# 10           FD011         14.2          Low Fat             0.05
# 11           FD012          6.3          Regular             0.04
# 12           FD013          8.8          Low Fat             0.07
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data.head()
# Out:
#   Item Identifier  Item Weight Item Fat Content  Item Visibility    Item Type  \
# 0           FD001         12.5          Low Fat             0.02        Dairy
# 1           FD002         10.0          Regular             0.03  Soft Drinks
# 2           FD003          9.3          Low Fat             0.05         Meat
# 3           FD004          5.5          Regular             0.07       Fruits
# 4           FD005          6.8          Low Fat             0.09   Vegetables
#
#    Item MRP Outlet Identifier  Outlet Establishment Year Outlet Size  \
# 0     240.5            OUT010                       1998      Medium
# 1      50.5            OUT017                       2007        High
# 2      60.5            OUT027                       1985       Small
# 3      80.0            OUT035                       2004      Medium
# 4      70.5            OUT045                       2002        High
#
#   Outlet Location Type        Outlet Type  Item Outlet Sales
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item Identifier            15 non-null     object
#  1   Item Weight                15 non-null     float64
#  2   Item Fat Content           15 non-null     object
#  3   Item Visibility            15 non-null     float64
#  4   Item Type                  15 non-null     object
#  5   Item MRP                   15 non-null     float64
#  6   Outlet Identifier          15 non-null     object
#  7   Outlet Establishment Year  15 non-null     int64
#  8   Outlet Size                15 non-null     object
#  9   Outlet Location Type       15 non-null     object
#  10  Outlet Type                15 non-null     object
#  11  Item Outlet Sales          15 non-null     float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.5+ KB

# %% [markdown]
# # Columns in the Data
#
# ```
#  data.columns
# ```

# %%
data.columns
# Out:
# Index(['Item Identifier', 'Item Weight', 'Item Fat Content', 'Item Visibility',
#        'Item Type', 'Item MRP', 'Outlet Identifier',
#        'Outlet Establishment Year', 'Outlet Size', 'Outlet Location Type',
#        'Outlet Type', 'Item Outlet Sales'],
#       dtype='object')

# %% [markdown]
# # Describe Data
# *The dataset provided for the big sales prediction project includes various features related to items and outlets, which are crucial for predicting the sales of items at different outlets*.
#
# ```
# data.describe()
# ```

# %%
data.describe()
# Out:
#        Item Weight  Item Visibility    Item MRP  Outlet Establishment Year  \
# count    15.000000        15.000000   15.000000                  15.000000
# mean      9.346667         0.048667  128.033333                2000.666667
# std       2.615849         0.022636   59.164971                   7.412987
# min       5.500000         0.020000   50.500000                1985.000000
# 25%       7.350000         0.030000   82.750000                1998.500000
# 50%       9.000000         0.050000  120.000000                2002.000000
# 75%      10.750000         0.065000  170.500000                2004.500000
# max      14.200000         0.090000  240.500000                2010.000000
#
#        Item Outlet Sales
# count          15.000000
# mean         1382.439400
# std          1301.232674
# min           129.589000
# 25%           446.771000
# 50%           876.543000
# 75%          1828.334500
# max          4321.987000

# %%
data['Item Weight'].fillna(data.groupby(['Item Type'])['Item Weight'].transform('mean'),inplace=True)

# %% [markdown]
# # Information Data
# *It gives the information of the data*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item Identifier            15 non-null     object
#  1   Item Weight                15 non-null     float64
#  2   Item Fat Content           15 non-null     object
#  3   Item Visibility            15 non-null     float64
#  4   Item Type                  15 non-null     object
#  5   Item MRP                   15 non-null     float64
#  6   Outlet Identifier          15 non-null     object
#  7   Outlet Establishment Year  15 non-null     int64
#  8   Outlet Size                15 non-null     object
#  9   Outlet Location Type       15 non-null     object
#  10  Outlet Type                15 non-null     object
#  11  Item Outlet Sales          15 non-null     float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.5+ KB

# %%
data.describe()
# Out:
#        Item Weight  Item Visibility    Item MRP  Outlet Establishment Year  \
# count    15.000000        15.000000   15.000000                  15.000000
# mean      9.346667         0.048667  128.033333                2000.666667
# std       2.615849         0.022636   59.164971                   7.412987
# min       5.500000         0.020000   50.500000                1985.000000
# 25%       7.350000         0.030000   82.750000                1998.500000
# 50%       9.000000         0.050000  120.000000                2002.000000
# 75%      10.750000         0.065000  170.500000                2004.500000
# max      14.200000         0.090000  240.500000                2010.000000
#
#        Item Outlet Sales
# count          15.000000
# mean         1382.439400
# std          1301.232674
# min           129.589000
# 25%           446.771000
# 50%           876.543000
# 75%          1828.334500
# max          4321.987000

# %%
data.dtypes
# Out:
# Item Identifier               object
# Item Weight                  float64
# Item Fat Content              object
# Item Visibility              float64
# Item Type                     object
# Item MRP                     float64
# Outlet Identifier             object
# Outlet Establishment Year      int64
# Outlet Size                   object
# Outlet Location Type          object
# Outlet Type                   object
# Item Outlet Sales            float64
# dtype: object

# %% [markdown]
# # NaN Values
# *To count the number of NaN values in a specific column in a Pandas DataFrame, we can use the isna() and sum() functions. The isna() function returns a Boolean value of True if the value is NaN and False otherwise. The sum() function returns the sum of True values, which equals the number of NaN values in the column*

# %%
data.isna().sum()
# Out:
# Item Identifier              0
# Item Weight                  0
# Item Fat Content             0
# Item Visibility              0
# Item Type                    0
# Item MRP                     0
# Outlet Identifier            0
# Outlet Establishment Year    0
# Outlet Size                  0
# Outlet Location Type         0
# Outlet Type                  0
# Item Outlet Sales            0
# dtype: int64

# %% [markdown]
# # Data Visualization
# *Data visualization is the process of using visual elements like charts, graphs, or maps to represent data. It translates complex, high-volume, or numerical data into a visual representation that is easier to process. Data visualization tools improve and automate the visual communication process for accuracy and detail.*

# %%
import matplotlib.pyplot as plt #visualization for outlier detection
plt.boxplot(data['Item Weight'])   #numeric values
plt.show()

# %%
import matplotlib.pyplot as plt #visualization for outlier detection
plt.boxplot(data['Item Outlet Sales'])   #numeric values
plt.show()

# %%
import matplotlib.pyplot as plt #visualization for outlier detection
plt.boxplot(data['Item MRP'])   #numeric values
plt.show()

# %%
import seaborn as sns
sns.pairplot(data)

# %% [markdown]
# # Get Categories and Counts of Categorial Variables
# *To get the categories and counts of categorical variables in the dataset, we can use the value_counts() method from pandas. This will help in understanding the distribution of different categories within each categorical feature. Here's how you can do it*
#
# In this dataset, the categorical variables are:
#
# *  Item_Fat_Content
# *  Item_Type
# *  Outlet_Identifier
# *  Outlet_Size
# *  Outlet_Location_Type
# *  Outlet_Type

# %%
data[['Item Identifier']].value_counts()
# Out:
# Item Identifier
# FD001              1
# FD002              1
# FD003              1
# FD004              1
# FD005              1
# FD006              1
# FD007              1
# FD008              1
# FD009              1
# FD010              1
# FD011              1
# FD012              1
# FD013              1
# FD014              1
# FD015              1
# Name: count, dtype: int64

# %% [markdown]
# *  Item Fat Content

# %%
data[['Item Fat Content']].value_counts()
# Out:
# Item Fat Content
# Low Fat             8
# Regular             7
# Name: count, dtype: int64

# %%
data.replace({'Item Fat Content':{'Low fat':0,'Regular':1}},inplace=True)

# %% [markdown]
# *  Item Type

# %%
print(data.columns)
data[['Item Type']].value_counts()
# Out:
# Index(['Item Identifier', 'Item Weight', 'Item Fat Content', 'Item Visibility',
#        'Item Type', 'Item MRP', 'Outlet Identifier',
#        'Outlet Establishment Year', 'Outlet Size', 'Outlet Location Type',
#        'Outlet Type', 'Item Outlet Sales'],
#       dtype='object')
# Item Type
# Baked Goods      1
# Beverages        1
# Breakfast        1
# Canned           1
# Dairy            1
# Frozen Foods     1
# Fruits           1
# Health Drinks    1
# Household        1
# Meat             1
# Seafood          1
# Snacks           1
# Soft Drinks      1
# Starchy Foods    1
# Vegetables       1
# Name: count, dtype: int64

# %%
data.replace({'Item Type':{'Fruits and Vegetables':0,'Snack Foods':0,'Household':1,
                           'Frozen Foods':0,'Dairy':0,'Baking Goods':0,
                           'Canned':0,'Health and Hygiene':1,
                           'Meat':0,'Soft Drinks':0,'Breads':0,'Hard Drinks':0,
                           'Others':2,'Starchy Foods':0,'BreakFast':0,'Seafood':0
                           }},inplace=True)

# %%
data[['Item Type']].value_counts()
# Out:
# Item Type
# 0                7
# 1                1
# Baked Goods      1
# Beverages        1
# Breakfast        1
# Fruits           1
# Health Drinks    1
# Snacks           1
# Vegetables       1
# Name: count, dtype: int64

# %% [markdown]
# *  Outlet Identifier

# %%
data[['Outlet Identifier']].value_counts()
# Out:
# Outlet Identifier
# OUT027               2
# OUT035               2
# OUT045               2
# OUT010               1
# OUT011               1
# OUT013               1
# OUT017               1
# OUT018               1
# OUT019               1
# OUT022               1
# OUT032               1
# OUT049               1
# Name: count, dtype: int64

# %%
data.replace({'Outlet Identifier':{'OUT027':0,'OUT013':1,'OUT027':0,
                                   'OUT049':2,'OUT035':4,
                                   'OUT045':5,'OUT018':6,
                                   'OUT017':7,'OUT010':8,'OUT019':9,
                                   }},inplace=True)

# %%
data[['Outlet Identifier']].value_counts()
# Out:
# Outlet Identifier
# 0                    2
# 4                    2
# 5                    2
# 1                    1
# 2                    1
# 6                    1
# 7                    1
# 8                    1
# 9                    1
# OUT011               1
# OUT022               1
# OUT032               1
# Name: count, dtype: int64

# %% [markdown]
# *   Outlet Size

# %%
data[['Outlet Size']].value_counts()
# Out:
# Outlet Size
# Medium         6
# High           5
# Small          4
# Name: count, dtype: int64

# %%
data.replace({'Outlet Size':{'Small':0,'Medium':1,'High':2}},inplace=True)

# %%
data[['Outlet Size']].value_counts()
# Out:
# Outlet Size
# 1              6
# 2              5
# 0              4
# Name: count, dtype: int64

# %% [markdown]
# *   Outlet Location Type

# %%
data[['Outlet Location Type']].value_counts()
# Out:
# Outlet Location Type
# 0                       5
# 1                       5
# 2                       5
# Name: count, dtype: int64

# %%
data.replace({'Outlet Location Type':{'Tier 1':0,'Tier 2':1,'Tier 3':2}},inplace=True)

# %%
data[['Outlet Location Type']].value_counts()
# Out:
# Outlet Location Type
# 0                       5
# 1                       5
# 2                       5
# Name: count, dtype: int64

# %%
data[['Outlet Type']].value_counts()
# Out:
# Outlet Type
# Supermarket Type1    5
# Supermarket Type2    4
# Grocery Store        3
# Supermarket Type3    3
# Name: count, dtype: int64

# %%
data.replace({'Outlet Location Type':{'Grocery Store':0,'Supermarket Type1':1,'Supermarket Type2':2,'Supermarket Type3':3}},inplace=True)

# %%
data[['Outlet Type']].value_counts()
# Out:
# Outlet Type
# Supermarket Type1    5
# Supermarket Type2    4
# Grocery Store        3
# Supermarket Type3    3
# Name: count, dtype: int64

# %%
data.head()
# Out:
#   Item Identifier  Item Weight Item Fat Content  Item Visibility   Item Type  \
# 0           FD001         12.5          Low Fat             0.02           0
# 1           FD002         10.0                1             0.03           0
# 2           FD003          9.3          Low Fat             0.05           0
# 3           FD004          5.5                1             0.07      Fruits
# 4           FD005          6.8          Low Fat             0.09  Vegetables
#
#    Item MRP Outlet Identifier  Outlet Establishment Year  Outlet Size  \
# 0     240.5                 8                       1998            1
# 1      50.5                 7                       2007            2
# 2      60.5                 0                       1985            0
# 3      80.0                 4                       2004            1
# 4      70.5                 5                       2002            2
#
#    Outlet Location Type        Outlet Type  Item Outlet Sales
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item Identifier            15 non-null     object
#  1   Item Weight                15 non-null     float64
#  2   Item Fat Content           15 non-null     object
#  3   Item Visibility            15 non-null     float64
#  4   Item Type                  15 non-null     object
#  5   Item MRP                   15 non-null     float64
#  6   Outlet Identifier          15 non-null     object
#  7   Outlet Establishment Year  15 non-null     int64
#  8   Outlet Size                15 non-null     int64
#  9   Outlet Location Type       15 non-null     int64
#  10  Outlet Type                15 non-null     object
#  11  Item Outlet Sales          15 non-null     float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 1.5+ KB

# %% [markdown]
# # Shape of the DataFrame
# *The shape of a DataFrame is a tuple of array dimensions that tells the number of rows and columns of a given DataFrame*

# %%
data.shape
# Out:
# (15, 12)

# %% [markdown]
# # y(dependent or label or target variable)
# Item Outlet Sales: This variable
#
# *  Item Outlet Sales:
#
# *This variable represents the sales of the item in the outlet and is the target variable you want to predict or explain*.

# %%
y=data['Item Outlet Sales']

# %%
y.shape
# Out:
# (15,)

# %%
y
# Out:
# 0     3735.138
# 1      443.422
# 2     2097.270
# 3      732.380
# 4      994.705
# 5     2828.231
# 6     1559.399
# 7      366.710
# 8      288.209
# 9      129.589
# 10     450.120
# 11    1234.567
# 12     876.543
# 13     678.321
# 14    4321.987
# Name: Item Outlet Sales, dtype: float64

# %% [markdown]
# # X (independent or features of Attribute Vriable)
#
# Independent Variables:
#
# * Item Identifier
# * Item Weight
# * Item Fat Content
# *  Item Visibility
# *  Item Type
# *  Item MRP
# *  Outlet Identifier
# *  Outlet Establishment Year
# *   Outlet Size
# *   Outlet Location Type
# *  Outlet Type
#
# *These independent variables may influence the dependent variable, Item Outlet Sales, and can be used to build predictive models or perform statistical analysis*.

# %%
x= data.drop(['Item Identifier','Item Outlet Sales'],axis=1)

# %%
x.shape
# Out:
# (15, 10)

# %%
x
# Out:
#     Item Weight Item Fat Content  Item Visibility      Item Type  Item MRP  \
# 0          12.5          Low Fat             0.02              0     240.5
# 1          10.0                1             0.03              0      50.5
# 2           9.3          Low Fat             0.05              0      60.5
# 3           5.5                1             0.07         Fruits      80.0
# 4           6.8          Low Fat             0.09     Vegetables      70.5
# 5           7.2                1             0.02              0     120.8
# 6           8.1          Low Fat             0.04    Baked Goods     150.5
# 7          11.0                1             0.06              0     200.2
# 8          13.5          Low Fat             0.08      Breakfast     110.5
# 9           7.5                1             0.03  Health Drinks      90.0
# 10         14.2          Low Fat             0.05         Snacks     120.0
# ...

# %% [markdown]
# # X variables standardized
# *Standardizing the independent variables (X variables) is a common preprocessing step in many machine learning algorithms. It ensures that each feature contributes equally to the result and helps algorithms converge more quickly*
#
# Let's standardize the numerical independent variables in your dataset. These are:
#
# Item Weight
# Item Visibility
# Item MRP
# Outlet Establishment Year
#
# * Item Weight
# * Item Visibility
# * Item MRP
# * Outlet Establishment Year

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_std=data[['Item Weight','Item Visibility','Item MRP','Outlet Establishment Year']]
X_std=sc.fit_transform(X_std)
X_std
# Out:
# array([[ 1.24778224, -1.31087814,  1.96761796, -0.37235491],
#        [ 0.25852571, -0.85359507, -1.35645506,  0.88434292],
#        [-0.01846612,  0.06097108, -1.18150385, -2.18758511],
#        [-1.52213606,  0.97553722, -0.84034899,  0.46544364],
#        [-1.00772266,  1.89010336, -1.00655264,  0.18617746],
#        [-0.84944161, -1.31087814, -0.12654804,  1.1636091 ],
#        [-0.49330926, -0.39631199,  0.39305706, -0.23272182],
#        [ 0.65422832,  0.51825415,  1.26256458, -2.18758511],
#        [ 1.64348486,  1.43282029, -0.30674779,  0.18617746],
#        [-0.73073083, -0.85359507, -0.66539778,  0.46544364],
#        [ 1.92047669,  0.06097108, -0.14054414,  0.04654436],
#        [-1.20557396, -0.39631199,  0.21810584,  0.60507673],
#        [-0.21631743,  0.97553722, -0.74412582,  1.30324219],
#        [ 0.45637702,  0.51825415,  1.0928619 ,  0.32581055],
#        [-0.13717691, -1.31087814,  1.43401677, -0.6516211 ]])

# %%
x[['Item Weight','Item Visibility','Item MRP','Outlet Establishment Year']] = pd.DataFrame(X_std,columns=['Item Weight','Item Visibility','Item MRP','Outlet Establishment Year'])
print(x[['Item Weight','Item Visibility','Item MRP','Outlet Establishment Year']].dtypes)
# Out:
# Item Weight                  float64
# Item Visibility              float64
# Item MRP                     float64
# Outlet Establishment Year    float64
# dtype: object

# %%
x
# Out:
#     Item Weight Item Fat Content  Item Visibility      Item Type  Item MRP  \
# 0      1.247782          Low Fat        -1.310878              0  1.967618
# 1      0.258526                1        -0.853595              0 -1.356455
# 2     -0.018466          Low Fat         0.060971              0 -1.181504
# 3     -1.522136                1         0.975537         Fruits -0.840349
# 4     -1.007723          Low Fat         1.890103     Vegetables -1.006553
# 5     -0.849442                1        -1.310878              0 -0.126548
# 6     -0.493309          Low Fat        -0.396312    Baked Goods  0.393057
# 7      0.654228                1         0.518254              0  1.262565
# 8      1.643485          Low Fat         1.432820      Breakfast -0.306748
# 9     -0.730731                1        -0.853595  Health Drinks -0.665398
# 10     1.920477          Low Fat         0.060971         Snacks -0.140544
# ...

# %% [markdown]
# # Train Test Spilt
#
# *To perform a train-test split, we typically divide the dataset into two parts: one for training the model and one for testing it. This helps to evaluate the model's performance on unseen data. Let's proceed with a train-test split where 80% of the data will be used for training and 20% for testing*.
#
# *We'll use the independent variables (both numerical and categorical) to predict the dependent variable (Item Outlet Sales). For the categorical variables, we'll need to encode them before training the model*.
#
# 1.  Encode categorical variables.
# 2.  Split the dataset into training and testing sets
#
# Here are the steps we'll follow:
#
# Encode categorical variables.
# Split the dataset into training and testing sets.
#
# The dataset has been successfully split into training and testing sets:
#
# Training set: 12 samples, 51 features
# Testing set: 3 samples, 51 features
#
# *  Training set: 12 samples, 51 features
# *  Testing set: 3 samples, 51 features

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x[['Item Weight','Item Visibility','Item MRP','Outlet Establishment Year']],y,test_size=0.1,random_state=2529)

# %% [markdown]
# # Model Train
# *Model training in machine language is the process of feeding an ML algorithm with data to help identify and learn good values for all attributes involved. There are several types of machine learning models, of which the most common ones are supervised and unsupervised learning*

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(random_state=2529)
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=2529)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x[['Item Weight','Item Visibility','Item MRP','Outlet Establishment Year']],y,test_size=0.1,random_state=2529)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
selected_features = ['Item Weight', 'Item Visibility', 'Item MRP', 'Outlet Establishment Year']
x_train, x_test, y_train, y_test = train_test_split(
    x[selected_features], y, test_size=0.1, random_state=2529)

# %%
rfr = RandomForestRegressor(random_state=2529)
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=2529)

# %% [markdown]
# # Model Prediction
#
# *Predictive modelling largely overlaps with the field of machine learning. There are two types of predictive models. They are Classification models, that predict class membership, and Regression models that predict a number. These models are then made up of algorithms*

# %%
y_pred = rfr.predict(x_test)
print(y_pred.shape)
# Out:
# (2,)

# %% [markdown]
# # Model Evaluation
# *Model evaluation is the process of using different evaluation metrics to understand a machine learning model's performance, as well as its strengths and weaknesses. Model evaluation is important to assess the efficacy of a model during initial research phases, and it also plays a role in model monitoring*.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mean_squared_error(y_test, y_pred)
# Out:
# 438036.1056791884

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 655.8357649999994

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 438036.1056791884

# %%
r2_score(y_test, y_pred)
# Out:
# -15.605512672441144

# %% [markdown]
# # Visualization of Actual vs Predicted Results

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual Prices vs Predicted Prices')
plt.show()
